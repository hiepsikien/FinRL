0.0

# %% [markdown]
# <a id='4'></a>
# # Part 5. Build A Market Environment in OpenAI Gym-style
# The training process involves observing stock price change, taking an action and reward's calculation. By interacting with the market environment, the agent will eventually derive a trading strategy that may maximize (expected) rewards.
#
# Our market environment, based on OpenAI Gym, simulates stock markets with historical market data.

# %% [markdown]
# ## Data Split
# We split the data into training set and testing set as follows:
#
# Training data period: 2009-01-01 to 2020-07-01
#
# Trading data period: 2020-07-01 to 2021-10-31

# %%
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 11280
# 11340

# %%
train.tail()
# Out:
#             date  tic        open        high         low       close  \
# 2892  2020-06-30  UNH  288.570007  296.450012  287.660004  284.978760
# 2892  2020-06-30    V  191.490005  193.750000  190.160004  189.975372
# 2892  2020-06-30   VZ   54.919998   55.290001   54.360001   48.169014
# 2892  2020-06-30  WBA   42.119999   42.580002   41.759998   38.128494
# 2892  2020-06-30  WMT  119.220001  120.129997  118.540001  115.184006
#
#           volume  day      macd     boll_ub     boll_lb     rsi_30     cci_30  \
# 2892   2932900.0  1.0 -0.019286  300.970794  268.613861  52.413053 -25.914769
# 2892   9040100.0  1.0  1.044597  197.956662  184.302287  53.021033 -51.589496
# 2892  17414800.0  1.0 -0.417954   51.555481   46.593791  48.097049 -51.186655
# 2892   4782100.0  1.0 -0.082033   41.619006   35.639083  48.830197 -14.575539
# 2892   6836400.0  1.0 -0.879410  118.508931  112.593772  48.159676 -69.964744
#
#          dx_30  close_30_sma  close_60_sma    vix  turbulence
# 2892  1.846804    285.220255    278.269259  30.43   12.918662
# 2892  2.013358    190.720190    180.952010  30.43   12.918662
# 2892  8.508886     48.776547     49.209270  30.43   12.918662
# 2892  1.500723     38.225631     38.030221  30.43   12.918662
# 2892  3.847271    116.836410    118.756424  30.43   12.918662

# %%
trade.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2020-07-01  AAPL   91.279999   91.839996   90.977501   89.631210
# 0  2020-07-01  AMGN  235.520004  256.230011  232.580002  236.683350
# 0  2020-07-01   AXP   95.250000   96.959999   93.639999   91.078453
# 0  2020-07-01    BA  185.880005  190.610001  180.039993  180.320007
# 0  2020-07-01   CAT  129.380005  129.399994  125.879997  118.455780
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  3.005438   92.417433   79.936120  62.807152  107.496666
# 0    6575800.0  2.0  3.583844  229.038903  197.319534  61.279649  271.050757
# 0    3301000.0  2.0 -0.384905  109.215327   86.798775  48.504810  -66.306227
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.249466  128.246940  111.290107  52.865413   35.692909
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.730532     83.678529     77.481210  28.620001   53.068365
# 0  46.806139    211.753602    212.811096  28.620001   53.068365
# 0   3.142448     96.180266     89.702836  28.620001   53.068365
# 0  15.932920    176.472335    155.614168  28.620001   53.068365
# 0  14.457404    117.239537    111.578320  28.620001   53.068365

# %%
def describe_market(data:pd.DataFrame):
    changes = []
    for stock in trade.tic.unique():
        start = data[data["tic"]==stock].head(1)["close"].values
        end = data[data["tic"]==stock].tail(1)["close"].values
        change = list((end-start)/start)
        changes = changes + change
    df = pd.DataFrame(changes)
    print(df.describe())

# %%
describe_market(trade)
# Out:
#                0
# count  30.000000
# mean   -0.014221
# std     0.284839
# min    -0.508180
# 25%    -0.170123
# 50%    -0.048980
# 75%     0.139454
# max     0.783242

# %%
# Out:
#                0
# count  30.000000
# mean   -0.014221
# std     0.284839
# min    -0.508180
# 25%    -0.170123
# 50%    -0.048980
# 75%     0.139454
# max     0.783242

# %%
trade.tic.unique()
# Out:
# array(['AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM', 'CSCO', 'CVX', 'DIS',
#        'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'JPM', 'KO', 'MCD', 'MMM',
#        'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ', 'WBA', 'WMT'],
#       dtype=object)

# %%
INDICATORS
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 30, State Space: 301

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [1000] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for Training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**. Users are also encouraged to try **ElegantRL** and **Ray RLlib**.
# * FinRL includes fine-tuned standard DRL algorithms, such as DQN, DDPG, Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
agent = DRLAgent(env = env_train)

if_using_a2c = False
if_using_ddpg = False
if_using_ppo = True
if_using_td3 = False
if_using_sac = False

# %% [markdown]
# ### Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# ### Agent 1: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")

if if_using_a2c:
  # set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                             tb_log_name='a2c',
                             total_timesteps=50000) if if_using_a2c else None

# %% [markdown]
# ### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
    # set up logger
    tmp_path = RESULTS_DIR + '/ppo'
    new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
    # Set new logger
    model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to results/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                            tb_log_name='ppo',
                            total_timesteps=50000) if if_using_ppo else None
# Out:
# ---------------------------------
# | time/              |          |
# |    fps             | 209      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# | train/             |          |
# |    reward          | 3.613088 |
# ---------------------------------
# day: 375, episode: 10
# begin_total_asset: 6046242.39
# end_total_asset: 5758065.80
# total_reward: -288176.59
# total_cost: 96150.63
# total_trades: 10990
# Sharpe: 0.006
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 2           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011561094 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.6       |
# |    explained_variance   | 0.000635    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 143         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00816    |
# |    reward               | 0.77517927  |
# |    std                  | 1           |
# |    value_loss           | 370         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 178         |
# |    iterations           | 3           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010073941 |
# |    clip_fraction        | 0.0796      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.7       |
# |    explained_variance   | -0.00326    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 292         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0101     |
# |    reward               | -4.2394934  |
# |    std                  | 1.01        |
# |    value_loss           | 353         |
# -----------------------------------------
# day: 375, episode: 20
# begin_total_asset: 6046242.39
# end_total_asset: 6415702.29
# total_reward: 369459.90
# total_cost: 95966.73
# total_trades: 11065
# Sharpe: 0.286
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 4           |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015945442 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.8       |
# |    explained_variance   | -0.000577   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 186         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0153     |
# |    reward               | 5.5258384   |
# |    std                  | 1.01        |
# |    value_loss           | 364         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 5           |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.015348008 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.8       |
# |    explained_variance   | -0.000779   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 138         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0123     |
# |    reward               | 6.1401396   |
# |    std                  | 1.01        |
# |    value_loss           | 370         |
# -----------------------------------------
# day: 375, episode: 30
# begin_total_asset: 6046242.39
# end_total_asset: 6486320.35
# total_reward: 440077.96
# total_cost: 94448.68
# total_trades: 10981
# Sharpe: 0.315
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 6           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014805814 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.9       |
# |    explained_variance   | -0.000445   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 136         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0139     |
# |    reward               | 5.408874    |
# |    std                  | 1.01        |
# |    value_loss           | 420         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 176        |
# |    iterations           | 7          |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01322015 |
# |    clip_fraction        | 0.161      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43        |
# |    explained_variance   | 0.00139    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 146        |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0117    |
# |    reward               | -32.313587 |
# |    std                  | 1.02       |
# |    value_loss           | 370        |
# ----------------------------------------
# day: 375, episode: 40
# begin_total_asset: 6046242.39
# end_total_asset: 6150754.50
# total_reward: 104512.12
# total_cost: 95813.15
# total_trades: 10978
# Sharpe: 0.182
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 177         |
# |    iterations           | 8           |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014318103 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.1       |
# |    explained_variance   | 0.000886    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 135         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00985    |
# |    reward               | 20.235897   |
# |    std                  | 1.02        |
# |    value_loss           | 384         |
# -----------------------------------------
# day: 375, episode: 50
# begin_total_asset: 6046242.39
# end_total_asset: 6513444.38
# total_reward: 467201.99
# total_cost: 93681.57
# total_trades: 10917
# Sharpe: 0.326
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 9           |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.019813921 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.1       |
# |    explained_variance   | 0.00261     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 152         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0142     |
# |    reward               | 0.92084837  |
# |    std                  | 1.02        |
# |    value_loss           | 338         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 10          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.016902465 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.2       |
# |    explained_variance   | 0.00169     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 168         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0131     |
# |    reward               | 3.4504917   |
# |    std                  | 1.02        |
# |    value_loss           | 330         |
# -----------------------------------------
# day: 375, episode: 60
# begin_total_asset: 6046242.39
# end_total_asset: 6045874.00
# total_reward: -368.38
# total_cost: 94800.43
# total_trades: 10885
# Sharpe: 0.147
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 176        |
# |    iterations           | 11         |
# |    time_elapsed         | 127        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01945954 |
# |    clip_fraction        | 0.23       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43.4      |
# |    explained_variance   | 0.00166    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 155        |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0205    |
# |    reward               | 6.0301757  |
# |    std                  | 1.03       |
# |    value_loss           | 395        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 177         |
# |    iterations           | 12          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.025128432 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.5       |
# |    explained_variance   | 0.0035      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 159         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0106     |
# |    reward               | -0.69983304 |
# |    std                  | 1.03        |
# |    value_loss           | 308         |
# -----------------------------------------
# day: 375, episode: 70
# begin_total_asset: 6046242.39
# end_total_asset: 6572404.51
# total_reward: 526162.13
# total_cost: 89223.88
# total_trades: 10782
# Sharpe: 0.340
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 178         |
# |    iterations           | 13          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.018077306 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.6       |
# |    explained_variance   | 0.0052      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 176         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0125     |
# |    reward               | -1.8289614  |
# |    std                  | 1.03        |
# |    value_loss           | 330         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 177         |
# |    iterations           | 14          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.016888903 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.6       |
# |    explained_variance   | 0.0103      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 327         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0171     |
# |    reward               | 6.382622    |
# |    std                  | 1.04        |
# |    value_loss           | 350         |
# -----------------------------------------
# day: 375, episode: 80
# begin_total_asset: 6046242.39
# end_total_asset: 5908102.81
# total_reward: -138139.58
# total_cost: 95086.03
# total_trades: 10932
# Sharpe: 0.098
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 15          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.023959855 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.7       |
# |    explained_variance   | 0.0121      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 180         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0137     |
# |    reward               | 5.8755193   |
# |    std                  | 1.04        |
# |    value_loss           | 353         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 16          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.027862579 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.7       |
# |    explained_variance   | 7.95e-05    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 143         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00402     |
# |    reward               | 35.46434    |
# |    std                  | 1.04        |
# |    value_loss           | 339         |
# -----------------------------------------
# day: 375, episode: 90
# begin_total_asset: 6046242.39
# end_total_asset: 6671482.62
# total_reward: 625240.24
# total_cost: 91110.41
# total_trades: 10842
# Sharpe: 0.377
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 17          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011630783 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.8       |
# |    explained_variance   | 0.0201      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 183         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0122     |
# |    reward               | 1.0824361   |
# |    std                  | 1.04        |
# |    value_loss           | 433         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 18          |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.015597556 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.8       |
# |    explained_variance   | 0.0588      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 196         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0129     |
# |    reward               | -5.2074733  |
# |    std                  | 1.04        |
# |    value_loss           | 398         |
# -----------------------------------------
# day: 375, episode: 100
# begin_total_asset: 6046242.39
# end_total_asset: 6741433.91
# total_reward: 695191.53
# total_cost: 92694.83
# total_trades: 10796
# Sharpe: 0.405
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 173        |
# |    iterations           | 19         |
# |    time_elapsed         | 224        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.01590933 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43.8      |
# |    explained_variance   | 0.1        |
# |    learning_rate        | 0.00025    |
# |    loss                 | 187        |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0137    |
# |    reward               | 1.4062797  |
# |    std                  | 1.04       |
# |    value_loss           | 372        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 20          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.016314434 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.9       |
# |    explained_variance   | 0.0997      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 220         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0101     |
# |    reward               | 1.4558818   |
# |    std                  | 1.05        |
# |    value_loss           | 356         |
# -----------------------------------------
# day: 375, episode: 110
# begin_total_asset: 6046242.39
# end_total_asset: 6591838.97
# total_reward: 545596.59
# total_cost: 89525.28
# total_trades: 10702
# Sharpe: 0.345
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 21          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.016362412 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.9       |
# |    explained_variance   | 0.134       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 246         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0114     |
# |    reward               | 2.481788    |
# |    std                  | 1.05        |
# |    value_loss           | 388         |
# -----------------------------------------
# day: 375, episode: 120
# begin_total_asset: 6046242.39
# end_total_asset: 6679692.96
# total_reward: 633450.58
# total_cost: 94478.86
# total_trades: 10877
# Sharpe: 0.385
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 22          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012159283 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.9       |
# |    explained_variance   | 0.0819      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 225         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0127     |
# |    reward               | -3.3737757  |
# |    std                  | 1.05        |
# |    value_loss           | 357         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 23          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.016299292 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44         |
# |    explained_variance   | 0.0987      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 108         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0101     |
# |    reward               | 3.414241    |
# |    std                  | 1.05        |
# |    value_loss           | 306         |
# -----------------------------------------
# day: 375, episode: 130
# begin_total_asset: 6046242.39
# end_total_asset: 6780499.90
# total_reward: 734257.51
# total_cost: 89591.89
# total_trades: 10764
# Sharpe: 0.411
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 24          |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.016014457 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44         |
# |    explained_variance   | 0.0858      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 182         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0178     |
# |    reward               | 8.584185    |
# |    std                  | 1.05        |
# |    value_loss           | 435         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 25          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014536706 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44         |
# |    explained_variance   | 0.0722      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 160         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0121     |
# |    reward               | -6.7322845  |
# |    std                  | 1.05        |
# |    value_loss           | 395         |
# -----------------------------------------

# %% [markdown]
# ### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cuda device

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=30000) if if_using_td3 else None

# %% [markdown]
# ### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cuda device
# Logging to results/sac

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=40000) if if_using_sac else None
# Out:
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 32        |
# |    time_elapsed    | 45        |
# |    total_timesteps | 1504      |
# | train/             |           |
# |    actor_loss      | 46.5      |
# |    critic_loss     | 225       |
# |    ent_coef        | 0.102     |
# |    ent_coef_loss   | -68.6     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1403      |
# |    reward          | 0.9938217 |
# ----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 8          |
# |    fps             | 32         |
# |    time_elapsed    | 92         |
# |    total_timesteps | 3008       |
# | train/             |            |
# |    actor_loss      | 21.8       |
# |    critic_loss     | 113        |
# |    ent_coef        | 0.0939     |
# |    ent_coef_loss   | -74.7      |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 2907       |
# |    reward          | 0.31556737 |
# -----------------------------------
# day: 375, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1239219.75
# total_reward: 239219.75
# total_cost: 23075.48
# total_trades: 8372
# Sharpe: 0.615
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 12         |
# |    fps             | 32         |
# |    time_elapsed    | 138        |
# |    total_timesteps | 4512       |
# | train/             |            |
# |    actor_loss      | 5.2        |
# |    critic_loss     | 132        |
# |    ent_coef        | 0.0812     |
# |    ent_coef_loss   | -118       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 4411       |
# |    reward          | 0.42989156 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 16         |
# |    fps             | 33         |
# |    time_elapsed    | 177        |
# |    total_timesteps | 6016       |
# | train/             |            |
# |    actor_loss      | -14.4      |
# |    critic_loss     | 32.3       |
# |    ent_coef        | 0.069      |
# |    ent_coef_loss   | -127       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 5915       |
# |    reward          | 0.56671715 |
# -----------------------------------
# day: 375, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1250641.24
# total_reward: 250641.24
# total_cost: 23167.87
# total_trades: 7865
# Sharpe: 0.631
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 20         |
# |    fps             | 33         |
# |    time_elapsed    | 224        |
# |    total_timesteps | 7520       |
# | train/             |            |
# |    actor_loss      | -18.5      |
# |    critic_loss     | 34.3       |
# |    ent_coef        | 0.0592     |
# |    ent_coef_loss   | -135       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 7419       |
# |    reward          | 0.17661777 |
# -----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 33        |
# |    time_elapsed    | 270       |
# |    total_timesteps | 9024      |
# | train/             |           |
# |    actor_loss      | -7.59     |
# |    critic_loss     | 1.74e+03  |
# |    ent_coef        | 0.0509    |
# |    ent_coef_loss   | -143      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 8923      |
# |    reward          | 0.4754091 |
# ----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 28         |
# |    fps             | 33         |
# |    time_elapsed    | 315        |
# |    total_timesteps | 10528      |
# | train/             |            |
# |    actor_loss      | -21        |
# |    critic_loss     | 273        |
# |    ent_coef        | 0.0438     |
# |    ent_coef_loss   | -145       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 10427      |
# |    reward          | 0.18655592 |
# -----------------------------------
# day: 375, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1207399.43
# total_reward: 207399.43
# total_cost: 8915.93
# total_trades: 6606
# Sharpe: 0.558
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 32         |
# |    fps             | 33         |
# |    time_elapsed    | 359        |
# |    total_timesteps | 12032      |
# | train/             |            |
# |    actor_loss      | -27.1      |
# |    critic_loss     | 36.7       |
# |    ent_coef        | 0.0377     |
# |    ent_coef_loss   | -153       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 11931      |
# |    reward          | 0.55910206 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 36         |
# |    fps             | 33         |
# |    time_elapsed    | 404        |
# |    total_timesteps | 13536      |
# | train/             |            |
# |    actor_loss      | -35.1      |
# |    critic_loss     | 187        |
# |    ent_coef        | 0.0325     |
# |    ent_coef_loss   | -155       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 13435      |
# |    reward          | 0.33504304 |
# -----------------------------------
# day: 375, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1169176.32
# total_reward: 169176.32
# total_cost: 5397.87
# total_trades: 5792
# Sharpe: 0.492
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 40         |
# |    fps             | 33         |
# |    time_elapsed    | 449        |
# |    total_timesteps | 15040      |
# | train/             |            |
# |    actor_loss      | -34.8      |
# |    critic_loss     | 40.9       |
# |    ent_coef        | 0.028      |
# |    ent_coef_loss   | -159       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 14939      |
# |    reward          | 0.38405412 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 44         |
# |    fps             | 33         |
# |    time_elapsed    | 497        |
# |    total_timesteps | 16544      |
# | train/             |            |
# |    actor_loss      | -33.3      |
# |    critic_loss     | 15.9       |
# |    ent_coef        | 0.0242     |
# |    ent_coef_loss   | -160       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 16443      |
# |    reward          | 0.35870218 |
# -----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 33        |
# |    time_elapsed    | 539       |
# |    total_timesteps | 18048     |
# | train/             |           |
# |    actor_loss      | -33.9     |
# |    critic_loss     | 3.72      |
# |    ent_coef        | 0.0208    |
# |    ent_coef_loss   | -168      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 17947     |
# |    reward          | 0.2380694 |
# ----------------------------------
# day: 375, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1142310.58
# total_reward: 142310.58
# total_cost: 4309.42
# total_trades: 5677
# Sharpe: 0.447
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 52         |
# |    fps             | 33         |
# |    time_elapsed    | 586        |
# |    total_timesteps | 19552      |
# | train/             |            |
# |    actor_loss      | -32.2      |
# |    critic_loss     | 2.64       |
# |    ent_coef        | 0.0179     |
# |    ent_coef_loss   | -168       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 19451      |
# |    reward          | 0.33927885 |
# -----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 33        |
# |    time_elapsed    | 631       |
# |    total_timesteps | 21056     |
# | train/             |           |
# |    actor_loss      | -31       |
# |    critic_loss     | 5.84      |
# |    ent_coef        | 0.0154    |
# |    ent_coef_loss   | -176      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 20955     |
# |    reward          | 0.4051986 |
# ----------------------------------
# day: 375, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1189345.85
# total_reward: 189345.85
# total_cost: 4380.00
# total_trades: 5987
# Sharpe: 0.530
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 33        |
# |    time_elapsed    | 675       |
# |    total_timesteps | 22560     |
# | train/             |           |
# |    actor_loss      | -30.4     |
# |    critic_loss     | 1.4       |
# |    ent_coef        | 0.0133    |
# |    ent_coef_loss   | -187      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 22459     |
# |    reward          | 0.3635427 |
# ----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 64         |
# |    fps             | 33         |
# |    time_elapsed    | 720        |
# |    total_timesteps | 24064      |
# | train/             |            |
# |    actor_loss      | -24.6      |
# |    critic_loss     | 2.12       |
# |    ent_coef        | 0.0114     |
# |    ent_coef_loss   | -192       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 23963      |
# |    reward          | 0.32544646 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 68         |
# |    fps             | 33         |
# |    time_elapsed    | 764        |
# |    total_timesteps | 25568      |
# | train/             |            |
# |    actor_loss      | -25.6      |
# |    critic_loss     | 6.11       |
# |    ent_coef        | 0.00982    |
# |    ent_coef_loss   | -200       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 25467      |
# |    reward          | 0.43138647 |
# -----------------------------------
# day: 375, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1182370.10
# total_reward: 182370.10
# total_cost: 4554.37
# total_trades: 6353
# Sharpe: 0.518
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 33        |
# |    time_elapsed    | 810       |
# |    total_timesteps | 27072     |
# | train/             |           |
# |    actor_loss      | -24       |
# |    critic_loss     | 6.57      |
# |    ent_coef        | 0.00845   |
# |    ent_coef_loss   | -208      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 26971     |
# |    reward          | 0.5591385 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 33        |
# |    time_elapsed    | 858       |
# |    total_timesteps | 28576     |
# | train/             |           |
# |    actor_loss      | -23.6     |
# |    critic_loss     | 0.713     |
# |    ent_coef        | 0.00727   |
# |    ent_coef_loss   | -216      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 28475     |
# |    reward          | 0.6420524 |
# ----------------------------------
# day: 375, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 1229982.76
# total_reward: 229982.76
# total_cost: 4211.71
# total_trades: 6656
# Sharpe: 0.588
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 80         |
# |    fps             | 33         |
# |    time_elapsed    | 902        |
# |    total_timesteps | 30080      |
# | train/             |            |
# |    actor_loss      | -20.6      |
# |    critic_loss     | 1.3        |
# |    ent_coef        | 0.00625    |
# |    ent_coef_loss   | -212       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 29979      |
# |    reward          | 0.73211956 |
# -----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 84        |
# |    fps             | 33        |
# |    time_elapsed    | 945       |
# |    total_timesteps | 31584     |
# | train/             |           |
# |    actor_loss      | -19.1     |
# |    critic_loss     | 13.3      |
# |    ent_coef        | 0.00539   |
# |    ent_coef_loss   | -221      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 31483     |
# |    reward          | 0.6079449 |
# ----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 88         |
# |    fps             | 33         |
# |    time_elapsed    | 993        |
# |    total_timesteps | 33088      |
# | train/             |            |
# |    actor_loss      | -18.1      |
# |    critic_loss     | 1.96       |
# |    ent_coef        | 0.00464    |
# |    ent_coef_loss   | -230       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 32987      |
# |    reward          | 0.66976345 |
# -----------------------------------
# day: 375, episode: 90
# begin_total_asset: 1000000.00
# end_total_asset: 1276554.06
# total_reward: 276554.06
# total_cost: 4461.74
# total_trades: 6511
# Sharpe: 0.669
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 92        |
# |    fps             | 33        |
# |    time_elapsed    | 1041      |
# |    total_timesteps | 34592     |
# | train/             |           |
# |    actor_loss      | -17.9     |
# |    critic_loss     | 11.2      |
# |    ent_coef        | 0.004     |
# |    ent_coef_loss   | -227      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 34491     |
# |    reward          | 0.7994935 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 96        |
# |    fps             | 33        |
# |    time_elapsed    | 1082      |
# |    total_timesteps | 36096     |
# | train/             |           |
# |    actor_loss      | -15.7     |
# |    critic_loss     | 0.39      |
# |    ent_coef        | 0.00345   |
# |    ent_coef_loss   | -227      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 35995     |
# |    reward          | 0.9040884 |
# ----------------------------------
# day: 375, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 1296913.76
# total_reward: 296913.76
# total_cost: 4238.77
# total_trades: 6241
# Sharpe: 0.709
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 100       |
# |    fps             | 33        |
# |    time_elapsed    | 1130      |
# |    total_timesteps | 37600     |
# | train/             |           |
# |    actor_loss      | -15.5     |
# |    critic_loss     | 0.195     |
# |    ent_coef        | 0.00298   |
# |    ent_coef_loss   | -219      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 37499     |
# |    reward          | 0.8783756 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 104       |
# |    fps             | 33        |
# |    time_elapsed    | 1174      |
# |    total_timesteps | 39104     |
# | train/             |           |
# |    actor_loss      | -13.4     |
# |    critic_loss     | 0.691     |
# |    ent_coef        | 0.00257   |
# |    ent_coef_loss   | -228      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 39003     |
# |    reward          | 0.8943423 |
# ----------------------------------

# %%
# %load_ext tensorboard

# %% [markdown]
# ## In-sample Performance
#
# Assume that the initial capital is $1,000,000.

# %% [markdown]
# ### Set turbulence threshold
# Set the turbulence threshold to be greater than the maximum of insample turbulence data. If current turbulence index is greater than the threshold, then we assume that the current market is volatile

# %%
data_risk_indicator = processed_full[(processed_full.date<TRAIN_END_DATE) & (processed_full.date>=TRAIN_START_DATE)]
insample_risk_indicator = data_risk_indicator.drop_duplicates(subset=['date'])

# %%
insample_risk_indicator.vix.describe()
# Out:
# count    376.000000
# mean      26.420479
# std       11.117699
# min       12.100000
# 25%       19.772501
# 50%       24.030001
# 75%       28.962500
# max       82.690002
# Name: vix, dtype: float64

# %%
insample_risk_indicator.vix.quantile(0.996)
# Out:
# 57.40400183105453

# %%
insample_risk_indicator.turbulence.describe()
# Out:
# count    2893.000000
# mean       34
df_account_value, df_actions = DRLAgent.DRL_prediction(
    model=trained_model, 
    environment = e_trade_gym)
# Out:
# hit end!

# %%
e_trade_gym

# %%
df_actions.to_csv("out/actions.csv")

# %%
df_account_value.shape
# Out:
# (378, 2)

# %%
df_account_value.tail(30)
# Out:
#            date  account_value
# 348  2022-11-16   5.467816e+06
# 349  2022-11-17   5.454069e+06
# 350  2022-11-18   5.482392e+06
# 351  2022-11-21   5.531090e+06
# 352  2022-11-22   5.576206e+06
# 353  2022-11-23   5.617460e+06
# 354  2022-11-25   5.626612e+06
# 355  2022-11-28   5.544623e+06
# 356  2022-11-29   5.530769e+06
# 357  2022-11-30   5.683880e+06
# 358  2022-12-01   5.684123e+06
# 359  2022-12-02   5.690501e+06
# 360  2022-12-05   5.603568e+06
# 361  2022-12-06   5.506982e+06
# 362  2022-12-07   5.504044e+06
# 363  2022-12-08   5.529507e+06
# 364  2022-12-09   5.501484e+06
# 365  2022-12-12   5.601876e+06
# 366  2022-12-13   5.642324e+06
# 367  2022-12-14   5.620445e+06
# 368  2022-12-15   5.480373e+06
# 369  2022-12-16   5.426050e+06
# 370  2022-12-19   5.362676e+06
# 371  2022-12-20   5.389662e+06
# 372  2022-12-21   5.449306e+06
# 373  2022-12-22   5.390016e+06
# 374  2022-12-23   5.417384e+06
# 375  2022-12-27   5.402769e+06
# 376  2022-12-28   5.341415e+06
# 377  2022-12-29   5.420473e+06

# %%
df_actions.head(30)
# Out:
#             AAPL  AMGN  AXP  BA  CAT  CRM  CSCO  CVX  DIS  DOW  ...  MRK  \
# date                                                            ...
# 2021-07-01     0     8    0   0   26    0    15    0    7    5  ...   11
# 2021-07-02     0     8    0   0   26    0    15    0    7    5  ...   11
# 2021-07-06     0     8    0   0   26    0    15    0    7    5  ...   11
# 2021-07-07     0     8    0   0   26    0    15    0    7    5  ...   11
# 2021-07-08     0     8    0   0   26    0    15    0    7    5  ...   11
# 2021-07-09     0     8    0   0   26    0    15    0    7    5  ...   11
# 2021-07-12     0     8    0   0   26    0    15    0    7    5  ...   11
# 2021-07-13     0     8    0   0   26    0    15    0    7    5  ...   11
# 2021-07-14     0     8    0   0   26    0    15    0    7    5  ...   11
# 2021-07-15     0     8    0   0   26    0    15    0    7    5  ...   11
# 2021-07-16     0     8    0   0   26    0    15    0    7    5  ...   11
# 2021-07-19     0     8    0   0   26    0    15    0    7    5  ...   11
# 2021-07-20     0     8    0   0   26    0    15    0    7    5  ...   11
# 2021-07-21     0     8    0   0   26    0    15    0    7    5  ...   11
# 2021-07-22     0     8    0   0   26    0    15    0    7    5  ...   11
# 2021-07-23     0     8    0   0   26    0    15    0    7    5  ...   11
# 2021-07-26     0     6    0   0   30    0    15    0   12   11  ...    8
# 2021-07-27     0     6    0   0   30    0    15    0   12   11  ...    8
# 2021-07-28     0     6    0   0   30    0    15    0   12   11  ...    8
# 2021-07-29     0     6    0   0   30    0    15    0   12   11  ...    8
# 2021-07-30     0     6    0   0   30    0    15    0   12   11  ...    8
# 2021-08-02     0     6    0   0   30    0    15    0   12   11  ...    8
# 2021-08-03     0     2    0   0   37    0    14    0    9    7  ...    4
# 2021-08-04     0    -2    0   0   33    0    14    0   12    8  ...    0
# 2021-08-05     0    -6    3   0   45    0     8    0   14   20  ...   -6
# 2021-08-06     0     0    0   0   44    0    19    0    3   21  ...    0
# 2021-08-09     0     0   -3   0    0    0    29    0    0    1  ...   -1
# 2021-08-10     0     0    0   0    0    0    28    0    0    2  ...    0
# 2021-08-11     0     0    0   0    0    0     4    0    0    0  ...    0
# 2021-08-12     0     0    0   0    0    0     5    0    0    0  ...    0
#
#             MSFT  NKE  PG  TRV  UNH  V  VZ  WBA  WMT
# date
# 2021-07-01     0    0  15    7    8  0   0   12    3
# 2021-07-02     0    0  15    7    8  0   0   12    3
# 2021-07-06     0    0  15    7    8  0   0   12    3
# 2021-07-07     0    0  15    7    8  0   0   12    3
# 2021-07-08     0    0  15    7    8  0   0   12    3
# 2021-07-09     0    0  15    7    8  0   0   12    3
# 2021-07-12     0    0  15    7    8  0   0   12    3
# 2021-07-13     0    0  15    7    8  0   0   12    3
# 2021-07-14     0    0  15    7    8  0   0   12    3
# 2021-07-15     0    0  15    7    8  0   0   12    3
# 2021-07-16     0    0  15    7    8  0   0   12    3
# 2021-07-19     0    0  15    7    8  0   0   12    3
# 2021-07-20     0    0  15    7    8  0   0   12    3
# 2021-07-21     0    0  15    7    8  0   0   12    3
# 2021-07-22     0    0  15    7    8  0   0   12    3
# 2021-07-23     0    0  15    7    8  0   0   12    3
# 2021-07-26     0    0  16    4   10  0   0    7    5
# 2021-07-27     0    0  16    4   10  0   0    7    5
# 2021-07-28     0    0  16    4   10  0   0    7    5
# 2021-07-29     0    0  16    4   10  0   0    7    5
# 2021-07-30     0    0  16    4   10  0   0    7    5
# 2021-08-02     0    0  16    4   10  0   0    7    5
# 2021-08-03     0    0  14    2   15  0   0    5    5
# 2021-08-04     0    0  13    0   13  0   0    5    4
# 2021-08-05     0    0  -9  -14    4  0   0   -8    4
# 2021-08-06     0    0  -6   -9    0  0   0  -10    0
# 2021-08-09     0    0 -12    0    0  0   0   -2   -4
# 2021-08-10     0    0 -15    0    0  0   0   -3   -6
# 2021-08-11     0    0 -14    0    0  0   0   -4    0
# 2021-08-12     0    0 -14    0    0  0   0   -4    0
#
# [30 rows x 30 columns]

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtesting Results
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
perf_stats_all.to_csv("./"+RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.075403
# Cumulative returns    -0.110945
# Annual volatility      0.189415
# Sharpe ratio          -0.320382
# Calmar ratio          -0.307400
# Stability              0.690760
# Max drawdown          -0.245293
# Omega ratio            0.947867
# Sortino ratio         -0.443700
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.957822
# Daily value at risk   -0.024105
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (335, 8)
# Annual return          0.273520
# Cumulative returns     0.379084
# Annual volatility      0.139248
# Sharpe ratio           1.811893
# Calmar ratio           3.062662
# Stability              0.918651
# Max drawdown          -0.089308
# Omega ratio            1.351851
# Sortino ratio          2.684720
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.051856
# Daily value at risk   -0.016542
# dtype: float64

# %%
df_account_value.loc[0,'date']
# Out:
# '2020-07-01'

# %%
df_account_value.loc[len(df_account_value)-1,'date']
# Out:
# '2021-10-28'

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
             baseline_ticker = '^DJI', 
             baseline_start = df_account_value.loc[0,'date'],
             baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (377, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-07-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-12-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>18</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-7.5%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-11.1%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>18.9%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.32</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.31</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.69</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-24.5%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.95</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-0.44</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.96</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.4%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.04</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>1.04</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>24.53</td>
#       <td>2021-11-08</td>
#       <td>2022-10-11</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.98</td>
#       <td>2021-08-16</td>
#       <td>2021-09-30</td>
#       <td>2021-10-19</td>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2.48</td>
#       <td>2021-07-15</td>
#       <td>2021-07-19</td>
#       <td>2021-07-23</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.87</td>
#       <td>2021-07-02</td>
#       <td>2021-07-08</td>
#       <td>2021-07-09</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.82</td>
#       <td>2021-07-26</td>
#       <td>2021-08-04</td>
#       <td>2021-08-06</td>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.02%</td>
#       <td>-3.89%</td>
#       <td>4.30%</td>
#     </tr>
#   </tbody>
# </table>

# %%
trade["tic"].unique()
# Out:
# array(['AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM', 'CSCO', 'CVX', 'DIS',
#        'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'JPM', 'KO', 'MCD',
#        'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ', 'WBA',
#        'WMT'], dtype=object)

# %%
trade.loc[trade["tic"]=='MSFT']["close"].plot()
# Out:
# <AxesSubplot: >

# %%
action
